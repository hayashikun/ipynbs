# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd

# %%
# example of display

from IPython.display import display, HTML, Math, YouTubeVideo

df = pd.read_csv("./wiki_flower_list.csv", header=0, index_col=0)
display(df)

display(HTML("<a href='http://hayashikun.com' target='__blank'><img src='http://hayashikun.com/imgs/kamon.png' width=200 /></a>"))

display(Math(r"i\hbar {\frac {d}{dt}} | \psi (t) \rangle ={\hat {H}} | \psi (t) \rangle"))

display(YouTubeVideo("Zi_XLOBDo_Y"))
# Out:
#             name                                                url
# 0           アサガオ  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%82%...
# 1           アジサイ  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%82%...
# 2         アツモリソウ  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%...
# 3           アネモネ  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%...
# 4           アブラナ  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%...
# 5          アマリリス  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%...
# 6            アヤメ  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%...
# 7      アルストロメリア属  https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%...
# 8            イチゴ  https://ja.wikipedia.org/wiki/%E3%82%A4%E3%83%...
# 9        イブキトラノオ  https://ja.wikipedia.org/wiki/%E3%82%A4%E3%83%...
# 10            ウメ   https://ja.wikipedia.org/wiki/%E3%82%A6%E3%83%A1
# 11       エゾエンゴサク  https://ja.wikipedia.org/wiki/%E3%82%A8%E3%82%...
# 12       オオヤマザクラ  https://ja.wikipedia.org/wiki/%E3%82%AA%E3%82%...
# ...
